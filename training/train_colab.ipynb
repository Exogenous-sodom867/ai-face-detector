# %% [markdown]
# # 🤖 AI Face Detector - Training on Google Colab
#
# This notebook trains a MobileNetV2 model to detect AI-generated faces.
#
# ## ⚡ Setup
#
# 1. **Enable GPU**: Runtime > Change runtime type > GPU
# 2. **Run cells sequentially**

# %% [markdown]
# ## 📦 Clone Repository

# %%
# !git clone https://github.com/furkankoykiran/ai-face-detector.git
# %cd ai-face-detector
# !ls -la

# %% [markdown]
# ## 🔧 Install Dependencies

# %%
# !pip install -q torch torchvision pillow matplotlib tqdm scikit-learn

# %% [markdown]
# ## 📊 Download Dataset (Option 1: Kaggle CLI)

# %%
# Install Kaggle CLI
# !pip install -q kaggle

# Upload your kaggle.json (from Kaggle account settings)
from google.colab import files
print("Please upload your kaggle.json file...")
files.upload()

# Setup Kaggle API credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
print("✅ Kaggle API configured successfully!")

# %%
# Download dataset
# !kaggle datasets download -d xhlulu/140k-real-and-fake-faces

# Create data directory and extract dataset
# !mkdir -p /content/data
# !unzip -q 140k-real-and-fake-faces.zip -d /content/data
# !rm 140k-real-and-fake-faces.zip
print("✅ Dataset downloaded and extracted successfully!")

# %% [markdown]
# ## 📤 Upload Dataset (Option 2: Manual Upload)

# %%
# Alternative: Upload dataset manually
from google.colab import files
print("Please upload the dataset zip file...")
files.upload()

# Create data directory and extract if uploaded
# !mkdir -p /content/data
# !unzip -q '*.zip' -d /content/data
# !rm *.zip
print("✅ Dataset extracted successfully!")

# %% [markdown]
# ## 🚀 Start Training

# %%
# Check GPU
import torch
print(f"GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("⚠️ GPU not available - training will be slow!")

# %%
# Run training with correct data path for Colab
# !python training/train.py --data_path /content/data

# %% [markdown]
# ## 📥 Download Trained Model

# %%
# Download model.pth
from google.colab import files
files.download('model.pth')

# Download training history
files.download('training_history.json')

# Download evaluation report
files.download('evaluation_report.json')

# %% [markdown]
# ## 📈 View Training Curves

# %%
from IPython.display import Image
Image(filename='training_curves.png')

# %% [markdown]
# ## ✅ Next Steps
#
# 1. Download `model.pth`
# 2. Place it in your project root
# 3. Run the API:
# ```bash
# uvicorn app.main:app --reload
# ```
# 4. Open `static/index.html` in your browser
#
# **🎉 Congratulations! Your model is ready!**
